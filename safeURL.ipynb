# %%
import pandas as pd 
df1 = pd.read_csv("majestic_million.csv")


df1.size
# Out:
# 12000000

# %%
df_15k = df1.sample(n=15000, random_state=42)

# Save to CSV
df_15k.to_csv("dataset_15k_random.csv", index=False)

# %%
df2 = pd.read_csv("dataset_15k_random.csv")
df2['url'] = "https://" + df2['Domain']
df2
# Out:
#        GlobalRank  TldRank                     Domain  TLD  RefSubNets  \
# 0          987232    74668            hannahshope.org  org         239
# 1           79955    35822           boxingnews24.com  com        1181
# 2          567131     4160    mojedziecikreatywnie.pl   pl         346
# 3          500892   224605                 teleco.com  com         377
# 4           55400     1599              hackedbolt.ru   ru        1476
# ...           ...      ...                        ...  ...         ...
# 14995      551655     4227  cienciaempresarial.com.br   br         353
# 14996      404056    12646        kleingarten-bund.de   de         436
# 14997      472239    17861         mytimeactive.co.uk   uk         392
# 14998      653169   295422         casinogoodwins.com  com         312
# 14999      822339     4819     casinoselector-777.top  top         266
#
#        RefIPs                 IDN_Domain IDN_TLD  PrevGlobalRank  PrevTldRank  \
# ...

# %%
df3= df2[["url"]]
df3["label"]=0
df3["source"]="majestic"
df3
# Out:
# /tmp/ipykernel_103710/3266535999.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["label"]=0
# /tmp/ipykernel_103710/3266535999.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["source"]="majestic"
#                                      url  label    source
# 0                https://hannahshope.org      0  majestic
# 1               https://boxingnews24.com      0  majestic
# 2        https://mojedziecikreatywnie.pl      0  majestic
# ...

# %%
df3
# Out:
#                                      url  label    source
# 0                https://hannahshope.org      0  majestic
# 1               https://boxingnews24.com      0  majestic
# 2        https://mojedziecikreatywnie.pl      0  majestic
# 3                     https://teleco.com      0  majestic
# 4                  https://hackedbolt.ru      0  majestic
# ...                                  ...    ...       ...
# 14995  https://cienciaempresarial.com.br      0  majestic
# 14996        https://kleingarten-bund.de      0  majestic
# 14997         https://mytimeactive.co.uk      0  majestic
# 14998         https://casinogoodwins.com      0  majestic
# 14999     https://casinoselector-777.top      0  majestic
#
# [15000 rows x 3 columns]

# %%
df3.to_csv("safe15kurls.csv", index=False)
