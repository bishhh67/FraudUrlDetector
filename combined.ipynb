# %%
import pandas as pd
df1= pd.read_csv("fraud_dset.csv")
df2= pd.read_csv("safe15kurls.csv")
print(df2.head())
print()
print(df1.head())
# Out:
#                                url  label    source
# 0          https://hannahshope.org      0  majestic
# 1         https://boxingnews24.com      0  majestic
# 2  https://mojedziecikreatywnie.pl      0  majestic
# 3               https://teleco.com      0  majestic
# 4            https://hackedbolt.ru      0  majestic
#
#                                            url  label     source
# 0  https://official-website.ghost.io/en-start/      1  phishtank
# 1   http://allegrolokalnie.oferta6311957.click      1  phishtank
# 2          https://allegro.45689459868945.sbs/      1  phishtank
# 3           https://allegro.45689459868945.sbs      1  phishtank
# 4    https://allegrolokalnie.l23arg45el4.click      1  phishtank

# %%
 #Combine them vertically
combined_df = pd.concat([df1, df2], ignore_index=True)

# Save to CSV
combined_df.to_csv("combined30k.csv", index=False)
